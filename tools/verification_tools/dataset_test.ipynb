# %% [markdown]
# # With Json Lines

# %%
import jsonlines as jsonl
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %%
file = "datasets/labeled_datasets/labeled_dataset_1683538348.jsonl"
dataset = {}
with jsonl.open(file) as reader:
    for line in reader:
        dataset.update(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 3
#       1 file = "datasets/labeled_datasets/labeled_dataset_1683538348.jsonl"
#       2 dataset = {}
# ----> 3 with jsonl.open(file) as reader:
#       4     for line in reader:
#       5         dataset.update(line)
#
# File ~/.pyenv/versions/pose-class/lib/python3.10/site-packages/jsonlines/jsonlines.py:627, in open(file, mode, loads, dumps, compact, sort_keys, flush)
#     625 cls = Reader if mode == "r" else Writer
#     626 encoding = "utf-8-sig" if mode == "r" else "utf-8"
# --> 627 fp = builtins.open(file, mode=mode + "t", encoding=encoding)
#     628 kwargs = dict(
#     629     loads=loads,
#     630     dumps=dumps,
#    (...)
#     633     flush=flush,
#     634 )
#     635 kwargs = {key: value for key, value in kwargs.items() if value is not None}
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/labeled_datasets/labeled_dataset_1683538348.jsonl'

# %%
print(f"top level keys: {dataset.keys()}")
print(f"properties: {dataset['props'].keys()}")
idx = 0
print(f"dataset size: {len(dataset['dataset'])}")
print(f"dataset: {dataset['dataset'][idx].keys()}")
# Out:
# top level keys: dict_keys([])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 print(f"top level keys: {dataset.keys()}")
# ----> 2 print(f"properties: {dataset['props'].keys()}")
#       3 idx = 0
#       4 print(f"dataset size: {len(dataset['dataset'])}")
#
# KeyError: 'props'

# %%
# -- data
idx = 2
print("filename:", dataset['dataset'][idx]['file_name'])
data = np.array(dataset['dataset'][idx]['data'])
print("data shape: ", data.shape)
keypoints = np.array(dataset['dataset'][idx]['kp'])
print("keypoints shape: ", keypoints.shape)
print("label:", dataset['dataset'][idx]['label'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 3
#       1 # -- data
#       2 idx = 2
# ----> 3 print("filename:", dataset['dataset'][idx]['file_name'])
#       4 data = np.array(dataset['dataset'][idx]['data'])
#       5 print("data shape: ", data.shape)
#
# KeyError: 'dataset'

# %%
frame = 15 # the frame to plot
# Create a figure. Equal aspect so circles look circular
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
ax.imshow(data[frame])
# -- draw keypoints
kp = keypoints.squeeze() # -- append to function
for k in range(17):
    circ = Circle((kp[frame][k][1],kp[frame][k][0]),3)
    ax.add_patch(circ)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 fig,ax = plt.subplots(1)
#       4 ax.set_aspect('equal')
# ----> 5 ax.imshow(data[frame])
#       6 # -- draw keypoints
#       7 kp = keypoints.squeeze() # -- append to function
#
# NameError: name 'data' is not defined

# %% [markdown]
# # With H5py

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import sys
sys.path.append("../")
from hdf5_utils import load_from_hdf5

# %%
file = "../datasets/unlabeled_datasets/unlabeled_videos1685530065.h5"
dataset_props, img_data, kp_data, file_name =  load_from_hdf5(file)
# Out:
# -- loading dataset --
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 file = "../datasets/unlabeled_datasets/unlabeled_videos1685530065.h5"
# ----> 2 dataset_props, img_data, kp_data, file_name =  load_from_hdf5(file)
#
# File ~/Documents/computer-vision-dev/al-pose-classification/tools/verification_tools/../hdf5_utils.py:47, in load_from_hdf5(path)
#      45 def load_from_hdf5(path):
#      46     print("-- loading dataset --")
# ---> 47     with h5py.File(path, 'r+') as f:
#      48         dataset = f['dataset']
#      49         dataset_keys = [key for key in dataset.keys()]
#
# File ~/.pyenv/versions/pose-class/lib/python3.10/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~/.pyenv/versions/pose-class/lib/python3.10/site-packages/h5py/_hl/files.py:233, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
# --> 233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     234 elif mode in ['w-', 'x']:
#     235     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '../datasets/unlabeled_datasets/unlabeled_videos1685530065.h5', errno = 2, error message = 'No such file or directory', flags = 1, o_flags = 2)

# %%
print("Dataset Properties: ",dataset_props)
print("Image data shape: ", img_data.shape)
print("Keypoint data shape: ", kp_data.shape)
print("File name: ", len(file_name))
# Out:
# Dataset Properties:  {'fps': 5.0, 'frame_count': 30, 'frames_saved': 20, 'height': 360, 'width': 640}
# Image data shape:  (76, 20, 360, 640, 3)
# Keypoint data shape:  (76, 20, 17, 3)
# File name:  76

# %%
video = 0
frame = 5 # the frame to plot
# Create a figure. Equal aspect so circles look circular
img = (img_data[video][frame]).astype(np.uint8)
h, w = img.shape[:2]
keypoints = kp_data[video]
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
ax.imshow(img)
# -- draw keypoints
kp = keypoints.squeeze() # -- append to function
for k in range(17):
    circ = Circle((kp[frame][k][0]*w, (kp[frame][k][1]*h)), 4)
    ax.add_patch(circ)

# %% [markdown]
# # Labeled Dataset

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import sys
sys.path.append("../")
from hdf5_utils import load_from_hdf5

# %%
file = "../datasets/labeled_datasets/labeled_dataset_1685611387.h5"
dataset_props, img_data, kp_data, file_name, targets =  load_from_hdf5(file)
# Out:
# -- loading dataset --
# ['file_name', 'img_data', 'kp_data', 'target']

# %%
print("Dataset Properties: ",dataset_props)
print("Image data shape: ", img_data.shape)
print("Keypoint data shape: ", kp_data.shape)
print("File name: ", len(file_name))
# Out:
# Dataset Properties:  {'fps': 5.0, 'frame_count': 30, 'frames_saved': 20, 'height': 360, 'width': 640}
# Image data shape:  (76, 20, 360, 640, 3)
# Keypoint data shape:  (76, 20, 17, 3)
# File name:  76

# %%
video = 19
frame = 5 # the frame to plot
# Create a figure. Equal aspect so circles look circular
print(file_name[video])
print(targets[video])
img = (img_data[video][frame]).astype(np.uint8)
h, w = img.shape[:2]
keypoints = kp_data[video]
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
ax.imshow(img)
# -- draw keypoints
kp = keypoints.squeeze() # -- append to function

# -- debug: calculate center point
pose = keypoints
body_kp = [5,6,11,12]
body_coords = pose[body_kp,:2]
body_coords = body_coords.T
x = body_coords[0].mean()
y = body_coords[1].mean()
circ = Circle((x*w, y*h), 4, color='r')
print((pose[1] - x).shape)
ax.add_patch(circ)
#pose = pose.T
#print(pose[0].shape)
#print(x)
#pose[1] = (pose[1] - x) / 640
#pose[0] = (pose[0] - y) / 360

for k in range(17):
    circ = Circle((kp[frame][k][0]*w, (kp[frame][k][1]*h)), 4)
    ax.add_patch(circ)
# Out:
# pose_1685100735.avi
# [0 0 0 1 0 0 0 0]
# (17, 3)
